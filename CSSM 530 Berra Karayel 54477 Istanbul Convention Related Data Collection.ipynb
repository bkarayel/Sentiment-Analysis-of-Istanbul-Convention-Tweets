# %% [markdown]
# ## Istanbul Convention Related Data Collection
# ### Berra Karayel 0054477

# %%
import os
import pandas as pd

# %%
tweet_count = 500000
text_query = "istanbul sözleşmesi"
since_date = "2021-03-20"
until_date = "2022-03-20"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> berranlp2.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df5 = pd.read_json('berranlp2.json', lines=True)

# Displays first 5 entries from dataframe
tweets_df5
# Out:
#                                 _type  \
# 0      snscrape.modules.twitter.Tweet
# 1      snscrape.modules.twitter.Tweet
# 2      snscrape.modules.twitter.Tweet
# 3      snscrape.modules.twitter.Tweet
# 4      snscrape.modules.twitter.Tweet
# ...                               ...
# 57544  snscrape.modules.twitter.Tweet
# 57545  snscrape.modules.twitter.Tweet
# 57546  snscrape.modules.twitter.Tweet
# 57547  snscrape.modules.twitter.Tweet
# 57548  snscrape.modules.twitter.Tweet
#
#                                                      url  \
# 0      https://twitter.com/EbruBayrakErden/status/150...
# 1      https://twitter.com/k_bxsk/status/150530367696...
# 2      https://twitter.com/Aleyerdm0/status/150529920...
# 3      https://twitter.com/KUZOVALI/status/1505265086...
# 4      https://twitter.com/beyazkasimpati/status/1505...
# ...                                                  ...
# 57544  https://twitter.com/ebruvarken/status/13730617...
# ...

# %%
tweets=tweets_df4[['date','rawContent','id','hashtags']]

# %%
tweets.to_csv('istanbulsoz.csv', sep=',', index=False)

# %%
tweets2=tweets_df5[['date','rawContent','id','hashtags']]

# %%
tweets2
# Out:
#                            date  \
# 0     2022-03-19 22:34:55+00:00
# 1     2022-03-19 22:02:18+00:00
# 2     2022-03-19 21:44:32+00:00
# 3     2022-03-19 19:28:57+00:00
# 4     2022-03-19 18:36:13+00:00
# ...                         ...
# 57544 2021-03-20 00:00:17+00:00
# 57545 2021-03-20 00:00:16+00:00
# 57546 2021-03-20 00:00:14+00:00
# 57547 2021-03-20 00:00:10+00:00
# 57548 2021-03-20 00:00:00+00:00
#
#                                               rawContent                   id  \
# 0      TT listesinde kadın adı gördüğümde öldürüldüğü...  1505311887503900674
# 1      #YağmurSönmez vefat etmedi, öldürüldü! \n\nbir...  1505303676965040135
# 2      Bugün ülkemin beni değil katilimi korumayı ter...  1505299205404823553
# 3      @SONDEM_1453 O değilde hafız abim dikkat ettim...  1505265086813851655
# 4      hukuk sorunlu. istanbul sözleşmesi gibi kadını...  1505251813519507459
# ...                                                  ...                  ...
# ...

# %%
tweets2.to_csv('istanbulsoz2.csv', sep=',', index=False)

# %%
df=pd.concat([tweets,tweets2])

# %%
df
# Out:
#                            date  \
# 0     2022-03-19 22:34:55+00:00
# 1     2022-03-19 21:44:32+00:00
# 2     2022-03-19 17:59:59+00:00
# 3     2022-03-18 21:33:37+00:00
# 4     2022-03-18 15:55:17+00:00
# ...                         ...
# 57544 2021-03-20 00:00:17+00:00
# 57545 2021-03-20 00:00:16+00:00
# 57546 2021-03-20 00:00:14+00:00
# 57547 2021-03-20 00:00:10+00:00
# 57548 2021-03-20 00:00:00+00:00
#
#                                               rawContent                   id  \
# 0      TT listesinde kadın adı gördüğümde öldürüldüğü...  1505311887503900674
# 1      Bugün ülkemin beni değil katilimi korumayı ter...  1505299205404823553
# 2      #YağmurSönmez İstanbul Bakırköy’de bir AVM’nin...  1505242697044537352
# 3      #bergenfilmiBabalar kızlarınızı çok sevin ki \...  1504934069456494597
# 4      'Kadına Yönelik Şiddetle Mücadele Paneli'ne; K...  1504848925500612612
# ...                                                  ...                  ...
# ...

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#                            date  \
# 0     2022-03-19 22:34:55+00:00
# 1     2022-03-19 21:44:32+00:00
# 2     2022-03-19 17:59:59+00:00
# 3     2022-03-18 21:33:37+00:00
# 4     2022-03-18 15:55:17+00:00
# ...                         ...
# 99359 2021-03-20 00:00:17+00:00
# 99360 2021-03-20 00:00:16+00:00
# 99361 2021-03-20 00:00:14+00:00
# 99362 2021-03-20 00:00:10+00:00
# 99363 2021-03-20 00:00:00+00:00
#
#                                               rawContent                   id  \
# 0      TT listesinde kadın adı gördüğümde öldürüldüğü...  1505311887503900674
# 1      Bugün ülkemin beni değil katilimi korumayı ter...  1505299205404823553
# 2      #YağmurSönmez İstanbul Bakırköy’de bir AVM’nin...  1505242697044537352
# 3      #bergenfilmiBabalar kızlarınızı çok sevin ki \...  1504934069456494597
# 4      'Kadına Yönelik Şiddetle Mücadele Paneli'ne; K...  1504848925500612612
# ...                                                  ...                  ...
# ...

# %%
df=df.drop_duplicates(subset='rawContent')

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#                            date  \
# 0     2022-03-19 22:34:55+00:00
# 1     2022-03-19 21:44:32+00:00
# 2     2022-03-19 17:59:59+00:00
# 3     2022-03-18 21:33:37+00:00
# 4     2022-03-18 15:55:17+00:00
# ...                         ...
# 51687 2021-03-20 00:00:50+00:00
# 51688 2021-03-20 00:00:45+00:00
# 51689 2021-03-20 00:00:17+00:00
# 51690 2021-03-20 00:00:14+00:00
# 51691 2021-03-20 00:00:00+00:00
#
#                                               rawContent                   id  \
# 0      TT listesinde kadın adı gördüğümde öldürüldüğü...  1505311887503900674
# 1      Bugün ülkemin beni değil katilimi korumayı ter...  1505299205404823553
# 2      #YağmurSönmez İstanbul Bakırköy’de bir AVM’nin...  1505242697044537352
# 3      #bergenfilmiBabalar kızlarınızı çok sevin ki \...  1504934069456494597
# 4      'Kadına Yönelik Şiddetle Mücadele Paneli'ne; K...  1504848925500612612
# ...                                                  ...                  ...
# ...

# %%
df['rawContent'].copy()
df['rawContent']=df['rawContent'].dropna()

# %%
df
# Out:
#                            date  \
# 0     2022-03-19 22:34:55+00:00
# 1     2022-03-19 21:44:32+00:00
# 2     2022-03-19 17:59:59+00:00
# 3     2022-03-18 21:33:37+00:00
# 4     2022-03-18 15:55:17+00:00
# ...                         ...
# 51687 2021-03-20 00:00:50+00:00
# 51688 2021-03-20 00:00:45+00:00
# 51689 2021-03-20 00:00:17+00:00
# 51690 2021-03-20 00:00:14+00:00
# 51691 2021-03-20 00:00:00+00:00
#
#                                               rawContent                   id  \
# 0      TT listesinde kadın adı gördüğümde öldürüldüğü...  1505311887503900674
# 1      Bugün ülkemin beni değil katilimi korumayı ter...  1505299205404823553
# 2      #YağmurSönmez İstanbul Bakırköy’de bir AVM’nin...  1505242697044537352
# 3      #bergenfilmiBabalar kızlarınızı çok sevin ki \...  1504934069456494597
# 4      'Kadına Yönelik Şiddetle Mücadele Paneli'ne; K...  1504848925500612612
# ...                                                  ...                  ...
# ...

# %%
df.to_csv('istanbulsozlesmesi.csv')

# %%
df2=df[['date','rawContent','id']]

# %%
df2
# Out:
#                            date  \
# 0     2022-03-19 22:34:55+00:00
# 1     2022-03-19 21:44:32+00:00
# 2     2022-03-19 17:59:59+00:00
# 3     2022-03-18 21:33:37+00:00
# 4     2022-03-18 15:55:17+00:00
# ...                         ...
# 51687 2021-03-20 00:00:50+00:00
# 51688 2021-03-20 00:00:45+00:00
# 51689 2021-03-20 00:00:17+00:00
# 51690 2021-03-20 00:00:14+00:00
# 51691 2021-03-20 00:00:00+00:00
#
#                                               rawContent                   id
# 0      TT listesinde kadın adı gördüğümde öldürüldüğü...  1505311887503900674
# 1      Bugün ülkemin beni değil katilimi korumayı ter...  1505299205404823553
# 2      #YağmurSönmez İstanbul Bakırköy’de bir AVM’nin...  1505242697044537352
# 3      #bergenfilmiBabalar kızlarınızı çok sevin ki \...  1504934069456494597
# 4      'Kadına Yönelik Şiddetle Mücadele Paneli'ne; K...  1504848925500612612
# ...                                                  ...                  ...
# ...

# %%
df2.to_excel('istanbul4.xlsx')

# %%
df2.to_csv('istanbul4.csv')
